# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 8
# ---------------------------------------
#
# GOALS:
#
# 1. Load data into Python that you find online
# 2. Understand data types and fix some errors
# 3. Find your own data to play with
#
# ----------------------------------------------------------
#
# This homework has **5 questions** and **1 problem**.
#
# NOTE: Be kind to yourself. Working with data can be hard! Every data set is different. **Seriously** come get help! Come to lab!

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Try reading in some data - csv
#
# Go to the [Cal Fire Website](https://www.fire.ca.gov/incidents) and scroll to the bottom to see the Incident Data. We will download the file named **ALL DATA AS CSV** this should put the data file into your Downloads folder.
#
# Next you need to move the file **mapdataall.csv** from your Downloads folder into your Day8 folder where you are doing your homework. You can open your Downloads folder and drag the file into JupyterLab side bar. Then I can run the command
#
#     DF_raw = pd.read_csv('mapdataall.csv')
#
# to load the data and look at the data frame.

# %%
# Your code here
DF_raw = pd.read_csv('mapdataall.csv')
print (DF_raw.shape)
# Out:
# (2732, 23)

# %% [markdown]
# **Q1** How many variables and observations?
# There is 2732 observations with 23 varibles
#
# **Q2** How many different incident types are there?
# 1
# **Q3** Make a histogram of the acres burned and color the bars by whether or not the incident was a calfire incident. You will probably need to make a mask to remove very small and very large fires. How many fires burned more than 100,000 acres? What is the largest fire in the data?
#
# **Extra Q** EXTRA - CHALLENGE - See if you can create a graph that answers the question: Are fires getting bigger or more frequent over time? You get complete creative control on how to answer this question!

# %%
DF_raw.columns
# Out:
# Index(['incident_name', 'incident_is_final', 'incident_date_last_update',
#        'incident_date_created', 'incident_administrative_unit',
#        'incident_administrative_unit_url', 'incident_county',
#        'incident_location', 'incident_acres_burned', 'incident_containment',
#        'incident_control', 'incident_cooperating_agencies',
#        'incident_longitude', 'incident_latitude', 'incident_type',
#        'incident_id', 'incident_url', 'incident_date_extinguished',
#        'incident_dateonly_extinguished', 'incident_dateonly_created',
#        'is_active', 'calfire_incident', 'notification_desired'],
#       dtype='object')

# %%
# You will need to write some code to answer the questions.
my_variables = ['incident_acres_burned','calfire_incident']
DF_raw = DF_raw[my_variables]
show(DF_raw)
# Out:
# <table id="itables_e5954961_6581_469d_9054_df6672afaf88" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>incident_acres_burned</th>
#       <th>calfire_incident</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.1.5 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.12/dt_bundle.js';
#
#     document.querySelectorAll("#itables_e5954961_6581_469d_9054_df6672afaf88:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [[37.0, false], [122.0, true], [407.0, true], [30.0, false], [274.0, true], [6896.0, true], [75.0, true], [125.0, true], [2956.0, true], [354.0, true], [217.0, true], [75.0, true], [650.0, true], [4346.0, true], [40.0, true], [712.0, true], [91.0, true], [35.0, true], [25.0, true], [90.0, true], [303.0, true], [100.0, true], [2650.0, true], [50.0, true], [124.0, true], [2500.0, true], [1984.0, false], [149.0, true], [170.0, true], [500.0, false], [100.0, true], [298.0, true], [0.0, false], [28.0, true], [124.0, true], [30.0, true], [30274.0, true], [240.0, true], [42.0, true], [60.0, true], [96.0, true], [75.0, true], [108.0, true], [1708.0, true], [237.0, true], [35.0, true], [40.0, true], [480.0, true], [124.0, true], [46.0, true], [150.0, true], [25.0, true], [534.0, true], [274.0, true], [105.0, true], [492.0, true], [754.0, true], [502.0, true], [200.0, true], [50.0, true], [38.0, true], [7055.0, true], [85.0, true], [73.0, true], [43.0, true], [572.0, false], [50.0, true], [150.0, true], [27531.0, true], [0.0, false], [75.0, true], [25.0, true], [22992.0, false], [14754.0, false], [92.0, true], [150.0, true], [60.0, true], [612.0, true], [45.0, true], [500.0, true], [195.0, true], [158.0, true], [163.0, true], [40.0, true], [15.0, true], [31.0, true], [1070.0, false], [1383.0, true], [60.0, false], [38.0, true], [20292.0, true], [12503.0, false], [50.0, true], [116.0, true], [243.0, false], [27.0, true], [2264.0, true], [27440.0, false], [97.0, true], [40.0, true], [70.0, true], [46.0, true], [110.0, false], [8073.0, true], [513.0, false], [794.0, false], [196.0, true], [200.0, false], [11429.0, true], [413.0, false], [2060.0, false], [38.0, true], [97.0, false], [41.0, true], [3111.0, true], [134.0, false], [73.0, true], [268.0, false], [97.0, false], [52.0, true], [80.0, true], [68.0, false], [257314.0, true], [263.0, true], [30.0, true], [94.0, true], [98.0, true], [376.0, true], [159.0, true], [2236.0, false], [305.0, true], [40.0, true], [163.0, true], [33.0, true], [51.0, true], [120.0, true], [190.0, true], [64.0, true], [82.0, true], [3505.0, true], [50.0, true], [23.0, true], [40.0, true], [865.0, false], [1952.0, false], [333.0, true], [106.0, true], [125.0, false], [400.0, true], [57.0, true], [113.0, true], [2143.0, true], [29.0, true], [1548.0, true], [75.0, true], [632.0, true], [5367.0, false], [1457.0, false], [380.0, true], [50.0, true], [1995.0, true], [600.0, false], [175.0, true], [402.0, true], [269.0, true], [25.0, true], [40.0, true], [70.0, true], [130.0, true], [3895.0, false], [225.0, true], [120.0, true], [85.0, true], [4300.0, true], [30.0, true], [12661.0, true], [6488.0, true], [1469.0, true], [1651.0, false], [15.0, false], [217.0, true], [80.0, true], [75.0, true], [47.0, true], [38.0, true], [143.0, true], [1680.0, false], [72.0, true], [4240.0, true], [39736.0, true], [13153.0, true], [35302.0, true], [32416.0, true], [6258.0, false], [5503.0, true], [25.0, true], [10.0, true], [612.0, true], [101.0, true], [0.0, false], [20.0, true], [190.0, false], [274.0, false], [84.0, true], [4045.0, false], [461.0, true], [1375.0, true], [70.0, true], [210.0, false], [27.0, true], [311.0, false], [97717.0, true], [200.0, false], [968.0, false], [247.0, true], [320.0, true], [516.0, true], [48.0, true], [94.0, false], [20.0, false], [80.0, true], [137.0, true], [1049.0, true], [692.0, true], [20.0, true], [1542.0, false], [67.0, true], [38.0, true], [60.0, true], [55.0, true], [171.0, true], [31359.0, true], [158.0, true], [920.0, true], [135.0, true], [60.0, true], [533.0, true], [0.0, false], [415.0, false], [100.0, false], [19.0, true], [35.0, true], [170.0, true], [23.0, true], [150.0, true], [40.0, true], [18.0, true], [54.0, true], [95.0, true], [21.0, true], [214.0, true], [181.0, true], [25.0, true], [4250.0, true], [200.0, false], [25.0, true], [430.0, true], [24.0, true], [8051.0, true], [65.0, true], [26.0, true], [75.0, false], [116.0, true], [77.0, true], [167.0, fa ...

# %%
small_fires = 300
large_fires = 5000

# %%
 fig = px.histogram(masked_DF,
                    nbins=500,
                    x= 'incident_acres_burned',
                    color='calfire_incident',
                    color_discrete_sequence = ['darkcyan','darkgrey'])
mask = (DF_raw['incident_acres_burned']> small_fires) & (DF_raw['incident_acres_burned']<large_fires)
 masked_DF= DF_raw[mask]

# %%
fig.update_layout(
                title = 'histogram of acres burned by ire incidents',
                xaxis_title= 'acres burned',
                yaxis_title = 'number of incidents',
                legend_title = 'calfire_incident')
fig.show()

# %% [markdown]
# **(Click Here)**

# %%
# Extra Code

# %% [markdown]
# ## Try reading in some data from Wikipedia - html
#
# Here we will explore academy award winning films. Go to the [Wiki for the List of Academy Award Winning Films](https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films). Look at what type of data is there. How many tables? Any weird looking data?
#
# Now read the html data into Python and show the data in DF[0]

# %%
# i believe there are 4 tables , data looks clean fo the most part besides the yellow  boxes

# %%
# Here is some helper code
# This is code that will read in the data and then fix the Year column
my_website = "https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films"
DF = pd.read_html(my_website)
DF_raw = DF[0]
DF_raw['Year'] = DF_raw['Year'].apply(lambda x: int(x.split('/')[0]))
DF_raw['Year'].value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
DF_raw
# Out:
#                                                    Film  Year Awards  \
# 0                                           Oppenheimer  2023      7
# 1                                           Poor Things  2023      4
# 2                                  The Zone of Interest  2023      2
# 3                                      American Fiction  2023      1
# 4                                     Anatomy of a Fall  2023      1
# ...                                                 ...   ...    ...
# 1368                            The Yankee Doodle Mouse  1943      1
# 1369                                       The Yearling  1946      2
# 1370  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1371                         You Can't Take It with You  1938      2
# 1372                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      Nominations
# 0             13
# 1             11
# 2              5
# 3              5
# 4              5
# ...          ...
# 1368           1
# 1369           7
# 1370           1
# 1371           7
# 1372           7
#
# [1373 rows x 4 columns]

# %% [markdown]
# **Q4** Following along with the lecture notes or video, fix the data in the 'Awards' column.

# %%
# Your code here
DF_raw['Year']= DF_raw['Year'].apply(lambda x : x.split ('/')
[0])
# Out:
#               Year
# count  1373.000000
# mean   1975.864530
# std      27.416755
# min    1927.000000
# 25%    1952.000000
# 50%    1975.000000
# 75%    2000.000000
# max    2023.000000

# %%
year_data = DF_raw['Year'].value_counts()
DF_year = year_data.reset_index().rename(columns={"index":"value", 0: "count"})
DF_year
# Out:
#     Year  count
# 0   1945     21
# 1   1949     20
# 2   1942     20
# 3   1950     19
# 4   1948     19
# ..   ...    ...
# 91  1931     10
# 92  1932      9
# 93  1928      7
# 94  1929      6
# 95  1930      6
#
# [96 rows x 2 columns]

# %%
DF_raw['Year']= DF_raw['Year'].apply(lambda x : int(x))

# %% [markdown]
# **Q5** Now try to fix the data in the "Nominations" column - see if you can do it without looking at the answer.

# %%
DF_raw['Awards'] = DF_raw['Awards'].apply(lambda x: int(x.split('/')[0])
# Out:
#   Cell In[116], line 1
#     DF_raw['Awards'] = DF_raw['Awards'].apply(lambda x: int(x.split('/')[0])
#                                                                             ^
# SyntaxError: incomplete input

# %%
# Your code here
award_data = DF_raw['Awards'].value_counts()
DF_award = award_data.reset_index().rename(columns={"index" : "value", 0: "count"})
DF_award
# Out:
#     Awards  count
# 0        1    987
# 1        2    157
# 2        3     78
# 3        4     48
# 4        0     36
# 5        5     26
# 6        7     13
# 7        6     13
# 8        8      8
# 9       11      3
# 10       9      3
# 11      10      1

# %% [markdown]
# ## Problem 1
#
# Your homework today will be to see if you can find some data of your own. This can be the first steps you take toward your final project.
#
# You should:
#
# * Find some data online
# * Read that data into Python using the Pandas commands we learned
# * Look at the DataFrame - number of variables, number of observations, AND the dtypes. Comment on what you see.
# * Try to do summary statistics (.describe()). Does it work like expected?
# * Attempt to fix any data, or explain why the data does not need to be fixed.
# * Make some sort of graph using columns in your data.
